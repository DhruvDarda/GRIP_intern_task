# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gt = pd.read_csv('data/globalterrorism.csv')
gt.head()
# Out:
# C:\Users\DHRUV DARDA\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
gt.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#gt.drop(["eventid", "country", "region"], axis = 1, inplace = True)

# %%
#gt.head()

# %%
print(list(gt.columns))
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
gt.resolution.unique()
# Out:
# array([nan, '3/8/1970', '3/15/1970', ..., '3/23/2013', '12/9/2011',
#        '12/27/2011'], dtype=object)

# %%
gt = gt[gt.resolution.isna()]

# %%
gt['approxdate'].isna().sum()
# Out:
# 170280

# %%
gt['approxdate'].count()
# Out:
# 9191

# %%
gty = gt.groupby(["iyear", "imonth"]).count()
gty
# Out:
#               eventid  iday  approxdate  extended  resolution  country  \
# iyear imonth
# 1970  0             1     1           0         1           0        1
#       1            39    39           1        39           0       39
#       2            55    55           3        55           0       55
#       3            61    61           1        61           0       61
#       4            78    78           0        78           0       78
# ...               ...   ...         ...       ...         ...      ...
# 2017  8           968   968         152       968           0      968
#       9           838   838         140       838           0      838
#       10          805   805         120       805           0      805
#       11          804   804         140       804           0      804
#       12          749   749          86       749           0      749
#
#               country_txt  region  region_txt  provstate  ...  addnotes  \
# ...

# %%
gt["iyear"].plot.hist(bins = 48)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
len(gt['country_txt'].unique())
# Out:
# 205

# %%
#labels = gt.groupby(["country_txt"]).count()['eventid'].index#.plot.hist(bins = 205)

#x = np.array(list(gt.groupby(["country_txt"]).count()['eventid']))

#ax = plt.figure(figsize = (12,7))
#plt.hist(x, bins = 205)

# %%
gtg = gt.country_txt.value_counts().head(40)
ax = gtg.plot(kind='barh', figsize=(7, 12))
#ax.bar_label(ax.containers[-1], label_type='edge')
ax.margins(x=0.1)

# %%
gta1 = gt.attacktype1_txt.value_counts()
gta2 = gt.attacktype2_txt.value_counts()
gta3 = gt.attacktype3_txt.value_counts()

gtat = pd.concat([gta1,gta2,gta3])

ax = gta1.plot(kind='barh', figsize=(7, 7))
#ax.bar_label(ax.containers[-1], label_type='edge')
ax.margins(x=0.1)

# %%
gtt1 = gt.targtype1_txt.value_counts()

#gttt = pd.concat([gta1,gta2,gta3])

ax = gtt1.plot(kind='barh', figsize=(7, 7))

ax.margins(x=0.1)

# %%
gtt2 = gt.targtype2_txt.value_counts()

#gttt = pd.concat([gta1,gta2,gta3])

ax = gtt2.plot(kind='barh', figsize=(7, 7))

ax.margins(x=0.1)

# %%
gtw1 = gt.weaptype1_txt.value_counts()

#gttt = pd.concat([gta1,gta2,gta3])

ax = gtw1.plot(kind='barh', figsize=(7, 7))

ax.margins(x=0.1)
